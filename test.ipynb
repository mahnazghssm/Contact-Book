# %% [markdown]
# - ContactBook
# - method:
#     - add_contact(create)
#     - view_contact(read)
#     - update_contact(update)
#     - delete_contact(delete)

# %%
class ContactBook: 
    pass

# %%
book = ContactBook()

# %%
book.add_contact(
    name = "Mahnaz", 
    phone = 989123361052,
    email = "mahnaz.ghssm@gmail.com"
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 book.add_contact(
#       2     name = "Mahnaz",
#       3     phone = 989123361052,
#       4     email = "mahnaz.ghssm@gmail.com"
#       5 )
#
# AttributeError: 'ContactBook' object has no attribute 'add_contact'

# %%
book.view_contact()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 book.view_contact()
#
# AttributeError: 'ContactBook' object has no attribute 'view_contact'

# %%
book.update_contact(
    name = "mahnaz",
    # email ="newemail@gmail.com"
    phone = 987654345678
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 book.update_contact(
#       2     name = "mahnaz",
#       3     # email ="newemail@gmail.com"
#       4     phone = 987654345678
#       5 )
#
# AttributeError: 'ContactBook' object has no attribute 'update_contact'

# %% [markdown]
# {
#     "mahnaz":{
#         "phone": "989123361053",
#         "email": "mahnaz.ghssm@gmail.com"
#     },
#     "mona":{
#         "phone": "09876543234",
#         "email": "mona.ghssm@gmail.com"
#     }
# }

# %%
from collections import defaultdict


class ContactBook:
    def __init__(self):
        self.contacts = defaultdict(dict)

    def add_contact(self, name, phone, email = None):
        if name in self.contacts:
            print("Contact already exists!")
            return

        self.contacts[name]["phone"] = phone
        self.contacts[name]["email"] = email

# %%
book = ContactBook()

# %%
book.add_contact(
    name = "Mahnaz", 
    phone = 989123361053,
    email = "mahnaz.ghssm@gmail.com"
)

# %%
book.add_contact(
    name = "Mona", 
    phone = 9876543245678,
    email = "mona.ghssm@gmail.com"
)

# %%
book.contacts
# Out:
# defaultdict(dict,
#             {'Mahnaz': {'phone': 989123361053,
#               'email': 'mahnaz.ghssm@gmail.com'},
#              'Mona': {'phone': 9876543245678,
#               'email': 'mona.ghssm@gmail.com'}})

# %%
from collections import defaultdict


class ContactBook:
    def __init__(self):
        self.contacts = defaultdict(dict)

    def add_contact(self, name, phone, email = None):
        if name in self.contacts:
            print("Contact already exists!")
            return

        self.contacts[name]["phone"] = phone
        self.contacts[name]["email"] = email

    def view_contacts(self):
        for name, info in self.contacts.items():
            print(f"Name: {name}")
            print(f"Phone: {info['phone']}")
            print(f"Email: {info['email']}")
            print("-" * 50)

# %%
book = ContactBook()

# %%
book.add_contact(
    name = "Mahnaz", 
    phone = 989123361053,
    email = "mahnaz.ghssm@gmail.com"
)

# %%
book.add_contact(
    name = "Mona", 
    phone = 9876543245678,
    email = "mona.ghssm@gmail.com"
)

# %%
book.add_contact(
    name = "Maryam", 
    phone = 876545678,
    email = "maryam.mokhtar@gmail.com"
)

# %%
book.view_contacts()
# Out:
# Name: Mahnaz
# Phone: 989123361053
# Email: mahnaz.ghssm@gmail.com
# --------------------------------------------------
# Name: Mona
# Phone: 9876543245678
# Email: mona.ghssm@gmail.com
# --------------------------------------------------
# Name: Maryam
# Phone: 876545678
# Email: maryam.mokhtar@gmail.com
# --------------------------------------------------

# %%
from collections import defaultdict


class ContactBook:
    def __init__(self):
        self.contacts = defaultdict(dict)

    def add_contact(self, name, phone, email = None):
        if name in self.contacts:
            print("Contact already exists!")
            return

        self.contacts[name]["phone"] = phone
        self.contacts[name]["email"] = email

    def view_contacts(self):
        for name, info in self.contacts.items():
            print(f"Name: {name}")
            print(f"Phone: {info['phone']}")
            print(f"Email: {info['email']}")
            print("-" * 50)

    def delete_contact(self, name):
        if name in self.contacts:
            del self.contacts[name]
            print("contact deleted successfully!")
        else:
            print("contact not found!")

# %%
book = ContactBook()

# %%
book.add_contact(
    name = "Mahnaz", 
    phone = 989123361053,
    email = "mahnaz.ghssm@gmail.com"
)

# %%
book.add_contact(
    name = "Mona", 
    phone = 9876543245678,
    email = "mona.ghssm@gmail.com"
)

# %%
book.add_contact(
    name = "Maryam", 
    phone = 876545678,
    email = "maryam.mokhtar@gmail.com"
)

# %%
book.view_contacts()
# Out:
# Name: Mahnaz
# Phone: 989123361053
# Email: mahnaz.ghssm@gmail.com
# --------------------------------------------------
# Name: Mona
# Phone: 9876543245678
# Email: mona.ghssm@gmail.com
# --------------------------------------------------
# Name: Maryam
# Phone: 876545678
# Email: maryam.mokhtar@gmail.com
# --------------------------------------------------

# %%
book.delete_contact("Maryam")
# Out:
# contact deleted successfully!

# %%
book.view_contacts()
# Out:
# Name: Mahnaz
# Phone: 989123361053
# Email: mahnaz.ghssm@gmail.com
# --------------------------------------------------
# Name: Mona
# Phone: 9876543245678
# Email: mona.ghssm@gmail.com
# --------------------------------------------------

# %%
from collections import defaultdict


class ContactBook:
    def __init__(self):
        self.contacts = defaultdict(dict)

    def add_contact(self, name, phone, email = None):
        if name in self.contacts:
            print("Contact already exists!")
            return

        self.contacts[name]["phone"] = phone
        self.contacts[name]["email"] = email

    def view_contacts(self):
        for name, info in self.contacts.items():
            print(f"Name: {name}")
            print(f"Phone: {info['phone']}")
            print(f"Email: {info['email']}")
            print("-" * 50)

    def delete_contact(self, name):
        if name in self.contacts:
            del self.contacts[name]
            print("contact deleted successfully!")
        else:
            print("contact not found!")

    def update_contact(self, name, phone= None, email = None):
        if name in self.contacts:
            if phone:
                self.contacts[name]["phone"] = phone
            if email:
                self.contacts[name]["email"] = email

            print("contact updated successfully!")
            return

        print("contact not found")

# %%
book = ContactBook()

# %%
book.add_contact(
    name = "Mahnaz", 
    phone = 989123361053,
    email = "mahnaz.ghssm@gmail.com"
)

# %%
book.view_contacts()
# Out:
# Name: Mahnaz
# Phone: 989123361053
# Email: mahnaz.ghssm@gmail.com
# --------------------------------------------------

# %%
book.update_contact(
    "Mahnaz",
    phone = 989123334567
)
# Out:
# contact updated successfully!

# %%
book.view_contacts()
# Out:
# Name: Mahnaz
# Phone: 989123334567
# Email: mahnaz.ghssm@gmail.com
# --------------------------------------------------

# %%
if __name__ == "__main__":
    book = ContactBook()

    while True:
        print("\n\nWelcome to contact book application!")
        print("1. Add Contact")
        print("2. Edit Contact")
        print("3. View Contact")
        print("4. Delete Contact")
        print("5. Quite")

        user_choice = input("please choose an option: ")

        if user_choice == "5":
            break

        elif user_choice == "1":
            name = input("\nEnter contact name: ")
            phone = input("Enter contact phone")
            email = input("Enter contact email: ")

            book.add_contact(name, phone, email)

        elif user_choice == "2":
            name = input("\nEnter contact name: ")
            phone = input("Enter conact phone: ")
            email = input("Enter contact Email")

            book.update_contact(name, phone, email)

        elif user_choice == "3":
            print("\n\nList of contacts: ")
            book.view_contacts()

        elif user_choice == "4":
            name = input("\nEnter contact name: ")
            book.delete_contact(name)
# Out:
# Welcome to contact book application!
# 1. Add Contact
# 2. Edit Contact
# 3. View Contact
# 4. Delete Contact
# 5. Quite
